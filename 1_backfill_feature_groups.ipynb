# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#1EB182;"><img src="../../images/icon102.png" width="38px"></img> **Hopsworks Feature Store** </span><span style="font-width:bold; font-size: 3rem; color:#333;">- Part 01: Backfill Features to the Feature Store</span>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/logicalclocks/hopsworks-tutorials/blob/master/advanced_tutorials/{project_name}/{notebook_name}.ipynb)
#
#
# ## 🗒️ This notebook is divided into the following sections:
# 1. Fetch historical data
# 2. Connect to the Hopsworks feature store
# 3. Create feature groups and insert them to the feature store
#
# ![tutorial-flow](01_featuregroups.png)

# %% [markdown]
# ## <span style='color:#ff5f27'> 📝 Imports

# %%
import pandas as pd

from functions import *

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:#ff5f27'> 💽 Loading Historical Data</span>

# %% [markdown]
# #### <span style='color:#ff5f27'> 👩🏻‍🔬 Air Quality Data

# %%
df_air_quality = pd.read_csv('https://repo.hops.works/dev/davit/air_quality/air_quality.csv')
df_air_quality.head()
# Out:
#         city  aqi        date  iaqi_h  iaqi_p  iaqi_pm10  iaqi_t  o3_avg  \
# 0  Sundsvall   11  2022-09-06   34.30  1020.5         10   15.80      19
# 1       Kyiv    6  2022-09-06   98.78  1022.7          2   13.91      19
# 2  Stockholm   13  2022-09-06   59.00  1021.0         13   17.00      17
# 3      Malmo   23  2022-09-06   54.50  1019.0          4   17.30      27
# 4  Stockholm    1  2022-09-07   46.00  1022.0          1   16.00      18
#
#    o3_max  o3_min  pm10_avg  pm10_max  pm10_min  pm25_avg  pm25_max  pm25_min  \
# 0      25      13         3         4         2         7         8         6
# 1      27      11         7        11         4        23        39        14
# 2      25       6         6        12         3        14        30         9
# 3      32      24         5         5         3        10        11         8
# 4      26       8         7        10         4        16        21         8
#
#    uvi_avg  uvi_max  uvi_min
# 0        0        0        0
# 1        0        0        0
# 2        0        0        0
# 3        1        1        1
# 4        1        1        1

# %%
df_air_quality.date = df_air_quality.date.apply(timestamp_2_time)
df_air_quality.sort_values(by = ['city','date'],inplace = True,ignore_index = True)
#df_air_quality=df_air_quality.drop(columns=['uvi_max','uvi_avg','uvi_min'])
df_air_quality.head()
# Out:
#     city  aqi           date  iaqi_h  iaqi_p  iaqi_pm10  iaqi_t  o3_avg  \
# 0   Kyiv    6  1662415200000   98.78  1022.7          2   13.91      19
# 1   Kyiv    2  1662501600000   65.58  1020.0          1   21.02      22
# 2   Kyiv    4  1662588000000   99.90  1017.6          2   12.45      22
# 3   Kyiv    2  1662674400000   99.90  1021.3          1   10.00      20
# 4  Malmo   23  1662415200000   54.50  1019.0          4   17.30      27
#
#    o3_max  o3_min  pm10_avg  pm10_max  pm10_min  pm25_avg  pm25_max  pm25_min
# 0      27      11         7        11         4        23        39        14
# 1      32      10         9        12         5        29        43        15
# 2      32      10         9        12         5        29        43        15
# 3      33       6        10        17         5        33        56        16
# 4      32      24         5         5         3        10        11         8

# %% [markdown]
# #### <span style='color:#ff5f27'> 🌦 Weather Data

# %%
df_weather = pd.read_csv('https://repo.hops.works/dev/davit/air_quality/weather.csv')
df_weather=df_weather.drop(columns=['uvindex'])
df_weather.head(3)
# Out:
#         city        date  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0       Kyiv  2022-09-06     17.7      4.6  11.5          17.7           4.6
# 1  Sundsvall  2022-09-06     13.0      3.0   8.6          13.0           0.1
# 2  Stockholm  2022-09-06     15.9      7.8  12.0          15.9           7.1
#
#    feelslike  dew  humidity  ...  snowdepth  windgust  windspeed  winddir  \
# 0       11.5  1.8      55.3  ...        0.0      24.5        9.7    267.0
# 1        7.4  5.5      81.8  ...        0.0      31.0       14.3    192.9
# 2       11.8  7.0      73.6  ...        0.0      25.2       13.0     70.7
#
#    pressure  cloudcover  visibility  solarradiation  solarenergy  \
# 0    1022.3        34.8        24.1           227.5         19.6
# 1    1024.1        90.8        15.3           116.1         10.1
# 2    1022.0        59.5        15.3           132.5         11.6
#
#          conditions
# 0  Partially cloudy
# 1          Overcast
# 2  Partially cloudy
#
# [3 rows x 24 columns]

# %%
df_weather.date = df_weather.date.apply(timestamp_2_time)
df_weather.sort_values(by=['city', 'date'],inplace=True, ignore_index=True)

df_weather.head(3)
# Out:
#    city           date  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Kyiv  1662415200000     17.7      4.6  11.5          17.7           4.6
# 1  Kyiv  1662501600000     17.7      4.6  11.5          17.7           4.6
# 2  Kyiv  1662588000000     21.1      7.9  14.3          21.1           7.9
#
#    feelslike  dew  humidity  ...  snowdepth  windgust  windspeed  winddir  \
# 0       11.5  1.8      55.3  ...        0.0      24.5        9.7    267.0
# 1       11.5  1.8      55.3  ...        0.0      24.5        9.7    267.0
# 2       14.3  3.3      50.9  ...        0.0      24.8        9.7    132.9
#
#    pressure  cloudcover  visibility  solarradiation  solarenergy  \
# 0    1022.3        34.8        24.1           227.5         19.6
# 1    1022.3        34.8        24.1           227.5         19.6
# 2    1019.4        48.4        24.1           217.9         18.7
#
#          conditions
# 0  Partially cloudy
# 1  Partially cloudy
# 2  Partially cloudy
#
# [3 rows x 24 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## <span style="color:#ff5f27;"> 🔮 Connecting to Hopsworks Feature Store </span>

# %%
from platform import python_version
python_version()
# Out:
# '3.9.13'

# %%
pip uninstall hsfs hopsworks
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# !SET CONDA_DLL_SEARCH_MODIFICATION_ENABLE=1

# %%
pip install hopsworks
# Out:
# Requirement already satisfied: hopsworks in c:\users\user\anaconda3\lib\site-packages (3.0.4)
# Requirement already satisfied: mock in c:\users\user\anaconda3\lib\site-packages (from hopsworks) (4.0.3)
# Requirement already satisfied: hsml<3.1.0,>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from hopsworks) (3.0.3)
# Requirement already satisfied: pyjks in c:\users\user\anaconda3\lib\site-packages (from hopsworks) (20.0.0)
# Requirement already satisfied: hsfs[python]<3.1.0,>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from hopsworks) (3.0.4)
# Requirement already satisfied: pyhumps==1.6.1 in c:\users\user\anaconda3\lib\site-packages (from hopsworks) (1.6.1)
# Requirement already satisfied: furl in c:\users\user\anaconda3\lib\site-packages (from hopsworks) (2.1.3)
# Requirement already satisfied: boto3 in c:\users\user\anaconda3\lib\site-packages (from hopsworks) (1.24.28)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from hopsworks) (2.28.1)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from hopsworks) (4.64.1)
# Requirement already satisfied: sqlalchemy in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.4.39)
# Requirement already satisfied: markupsafe<2.1.0 in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.0.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.21.5)
# Requirement already satisfied: avro==1.10.2 in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.10.2)
# Requirement already satisfied: PyMySQL[rsa] in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.0.2)
# Requirement already satisfied: great-expectations==0.14.12 in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.14.12)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.4.4)
# Requirement already satisfied: confluent-kafka==1.8.2 in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.8.2)
# Requirement already satisfied: pyarrow in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (10.0.0)
# Requirement already satisfied: pyhopshive[thrift] in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.6.4.1.dev0)
# Requirement already satisfied: fastavro==1.4.11 in c:\users\user\anaconda3\lib\site-packages (from hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.4.11)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (4.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.8.2)
# Requirement already satisfied: importlib-metadata>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (4.11.3)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (7.6.5)
# Requirement already satisfied: pyparsing<3,>=2.4 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.4.7)
# Requirement already satisfied: Click>=7.1.2 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (8.0.4)
# Requirement already satisfied: mistune<2.0.0,>=0.8.4 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.8.4)
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python39\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (22.0)
# Requirement already satisfied: jinja2<3.1.0,>=2.10 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.11.3)
# Requirement already satisfied: jsonpatch>=1.22 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.32)
# Requirement already satisfied: jsonschema>=2.5.1 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (4.16.0)
# Requirement already satisfied: altair<5,>=4.0.0 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (4.2.0)
# Requirement already satisfied: scipy>=0.19.0 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.9.1)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.17.17)
# Requirement already satisfied: tzlocal>=1.2 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (4.2)
# Requirement already satisfied: colorama>=0.4.3 in c:\users\user\appdata\roaming\python\python39\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.4.6)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.26.11)
# Requirement already satisfied: nbformat>=5.0 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (5.5.0)
# Requirement already satisfied: cryptography>=3.2 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (37.0.1)
# Requirement already satisfied: pytz>=2021.3 in c:\users\user\anaconda3\lib\site-packages (from great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->hopsworks) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->hopsworks) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->hopsworks) (2.0.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\user\anaconda3\lib\site-packages (from boto3->hopsworks) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from boto3->hopsworks) (0.6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in c:\users\user\anaconda3\lib\site-packages (from boto3->hopsworks) (1.27.28)
# Requirement already satisfied: six>=1.8.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from furl->hopsworks) (1.16.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from furl->hopsworks) (1.0.1)
# Requirement already satisfied: javaobj-py3 in c:\users\user\anaconda3\lib\site-packages (from pyjks->hopsworks) (0.4.3)
# Requirement already satisfied: pyasn1-modules in c:\users\user\anaconda3\lib\site-packages (from pyjks->hopsworks) (0.2.8)
# Requirement already satisfied: pycryptodomex in c:\users\user\anaconda3\lib\site-packages (from pyjks->hopsworks) (3.15.0)
# Requirement already satisfied: pyasn1>=0.3.5 in c:\users\user\anaconda3\lib\site-packages (from pyjks->hopsworks) (0.4.8)
# Requirement already satisfied: twofish in c:\users\user\anaconda3\lib\site-packages (from pyjks->hopsworks) (0.3.0)
# Requirement already satisfied: future in c:\users\user\anaconda3\lib\site-packages (from pyhopshive[thrift]->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.18.2)
# Requirement already satisfied: thrift>=0.10.0 in c:\users\user\anaconda3\lib\site-packages (from pyhopshive[thrift]->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.1.1)
# Requirement already satisfied: toolz in c:\users\user\anaconda3\lib\site-packages (from altair<5,>=4.0.0->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.11.2)
# Requirement already satisfied: entrypoints in c:\users\user\appdata\roaming\python\python39\site-packages (from altair<5,>=4.0.0->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\user\anaconda3\lib\site-packages (from cryptography>=3.2->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.15.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata>=1.7.0->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (3.8.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (5.8.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (8.7.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (6.19.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\lib\site-packages (from jsonpatch>=1.22->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (21.4.0)
# Requirement already satisfied: jupyter_core in c:\users\user\appdata\roaming\python\python39\site-packages (from nbformat>=5.0->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (5.1.0)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\lib\site-packages (from nbformat>=5.0->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.16.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in c:\users\user\anaconda3\lib\site-packages (from ruamel.yaml<0.17.18,>=0.16->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.2.7)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\user\anaconda3\lib\site-packages (from tzlocal>=1.2->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\user\anaconda3\lib\site-packages (from tzlocal>=1.2->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2022.6)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.21)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\user\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.1.2)
# Requirement already satisfied: psutil in c:\users\user\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (5.9.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (7.4.8)
# Requirement already satisfied: debugpy>=1.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.6.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (24.0.1)
# Requirement already satisfied: pickleshare in c:\users\user\appdata\roaming\python\python39\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\user\appdata\roaming\python\python39\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.6.2)
# Requirement already satisfied: backcall in c:\users\user\appdata\roaming\python\python39\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.18.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.13.0)
# Requirement already satisfied: decorator in c:\users\user\appdata\roaming\python\python39\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\user\appdata\roaming\python\python39\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (3.0.36)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\user\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (6.4.12)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from jupyter_core->nbformat>=5.0->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.6.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from jupyter_core->nbformat>=5.0->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (305)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.13.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.8.0)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\roaming\python\python39\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\user\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.2.1)
# Requirement already satisfied: testpath in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.5.13)
# Requirement already satisfied: bleach in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (4.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.7.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->great-expectations==0.14.12->hsfs[python]<3.1.0,>=3.0.0->hopsworks) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import hopsworks

project = hopsworks.login()

fs = project.get_feature_store()
# Out:
# Connection closed.
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/5287
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\hsfs\engine\__init__.py:33, in init(engine_type)
#      32 try:
# ---> 33     from hsfs.engine import python
#      34 except ImportError:
#
# File ~\anaconda3\lib\site-packages\hsfs\engine\python.py:37
#      36 from typing import TypeVar, Optional, Dict, Any
# ---> 37 from confluent_kafka import Producer
#      38 from tqdm.auto import tqdm
#
# File ~\anaconda3\lib\site-packages\confluent_kafka\__init__.py:40
#      20 # end delvewheel patch
#      21
#      22 #!/usr/bin/env python
#    (...)
#      37 # limitations under the License.
#      38 #
# ---> 40 from .deserializing_consumer import DeserializingConsumer
#      41 from .serializing_producer import SerializingProducer
#
# File ~\anaconda3\lib\site-packages\confluent_kafka\deserializing_consumer.py:19
#       1 #!/usr/bin/env python
#       2 # -*- coding: utf-8 -*-
#       3 #
#    (...)
#      16 # limitations under the License.
#      17 #
# ---> 19 from confluent_kafka.cimpl import Consumer as _ConsumerImpl
#      20 from .error import (ConsumeError,
#      21                     KeyDeserializationError,
#      22                     ValueDeserializationError)
#
# ImportError: DLL load failed while importing cimpl: Le module spécifié est introuvable.
#
# During handling of the above exception, another exception occurred:
#
# FeatureStoreException                     Traceback (most recent call last)
# Cell In[16], line 5
#       1 import hopsworks
#       3 project = hopsworks.login()
# ----> 5 fs = project.get_feature_store()
#
# File ~\anaconda3\lib\site-packages\hopsworks\project.py:103, in Project.get_feature_store(self)
#     101 _client = client.get_instance()
#     102 if type(_client) == Client:  # If external client
# --> 103     return connection(
#     104         host=_client._host,
#     105         port=_client._port,
#     106         project=self.name,
#     107         api_key_value=_client._auth._token,
#     108         engine="python",
#     109     ).get_feature_store()
#     110 else:
#     111     return connection().get_feature_store()
#
# File ~\anaconda3\lib\site-packages\hsfs\connection.py:306, in Connection.connection(cls, host, port, project, engine, region_name, secrets_store, hostname_verification, trust_store_path, cert_folder, api_key_file, api_key_value)
#     290 @classmethod
#     291 def connection(
#     292     cls,
#    (...)
#     303     api_key_value: str = None,
#     304 ):
#     305     """Connection factory method, accessible through `hsfs.connection()`."""
# --> 306     return cls(
#     307         host,
#     308         port,
#     309         project,
#     310         engine,
#     311         region_name,
#     312         secrets_store,
#     313         hostname_verification,
#     314         trust_store_path,
#     315         cert_folder,
#     316         api_key_file,
#     317         api_key_value,
#     318     )
#
# File ~\anaconda3\lib\site-packages\hsfs\connection.py:139, in Connection.__init__(self, host, port, project, engine, region_name, secrets_store, hostname_verification, trust_store_path, cert_folder, api_key_file, api_key_value)
#     136 self._api_key_value = api_key_value
#     137 self._connected = False
# --> 139 self.connect()
#
# File ~\anaconda3\lib\site-packages\hsfs\decorators.py:25, in not_connected.<locals>.if_not_connected(inst, *args, **kwargs)
#      23 if inst._connected:
#      24     raise HopsworksConnectionError
# ---> 25 return fn(inst, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\hsfs\connection.py:216, in Connection.connect(self)
#     213     client.init("hopsworks")
#     215 # init engine
# --> 216 engine.init(self._engine)
#     218 self._feature_store_api = feature_store_api.FeatureStoreApi()
#     219 self._project_api = project_api.ProjectApi()
#
# File ~\anaconda3\lib\site-packages\hsfs\engine\__init__.py:35, in init(engine_type)
#      33     from hsfs.engine import python
#      34 except ImportError:
# ---> 35     raise exceptions.FeatureStoreException(
#      36         "Trying to instantiate Python as engine, but 'python' extras are "
#      37         "missing in HSFS installation. Install with `pip install "
#      38         "hsfs[python]`."
#      39     )
#      40 _engine_type = "python"
#      41 _engine = python.Engine()
#
# FeatureStoreException: Trying to instantiate Python as engine, but 'python' extras are missing in HSFS installation. Install with `pip install hsfs[python]`.

# %% [markdown]
# ---

# %% [markdown]
# ## <span style="color:#ff5f27;">🪄 Creating Feature Groups</span>

# %% [markdown]
# #### <span style='color:#ff5f27'> 👩🏻‍🔬 Air Quality Data

# %%
air_quality_fg = fs.get_or_create_feature_group(
        name = 'air_quality_fg',
        description = 'Air Quality characteristics of each day',
        version = 3,
        primary_key = ['city','date'],
        online_enabled = True,
        event_time = 'date'
    )    

air_quality_fg.insert(df_air_quality)

# %% [markdown]
# #### <span style='color:#ff5f27'> 🌦 Weather Data

# %%
weather_fg = fs.get_or_create_feature_group(
        name = 'weather_fg',
        description = 'Weather characteristics of each day',
        version = 3,
        primary_key = ['city','date'],
        online_enabled = True,
        event_time = 'date'
    )    

weather_fg.insert(df_weather)

# %% [markdown]
# ---
